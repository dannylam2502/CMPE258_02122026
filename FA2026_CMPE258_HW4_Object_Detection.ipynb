# %% [markdown]
# <a href="https://colab.research.google.com/github/dannylam2502/CMPE258_02122026/blob/main/FA2026_CMPE258_HW4_Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #SJSU SP2026 CMPE258 Introduction to Deep Learning
#
# # Homework 4: Train & Evaluate a YOLO Object Detector (5 points)
#
# Posted: 1/15/2025
# Due Date: 2/5/2025
#
# ### Name: I change something
# ### Email:
# ### Student no:
# ### Submission date:

# %% [markdown]
# The goal of this assignment is to detect and localize people and their safety gear in construction-site images, making it a multi-class object detection task.
# Each image may contain multiple workers who may or may not be wearing protective equipement such as helmets (hard hats) or safety vests.
# The model must be able to:
# *  Detect the presence of people and protective equipment.
# *  Classify each detected instance into categories such as “person with helmet”, “person without helmet”, “helmet”, “vest”, etc.
# *  Draw bounding boxes around each detected object instance.

# %% [markdown]
# Suggested Resources:
#
# *   Ultralytics YOLO docs (installation, training, formats, export): https://docs.ultralytics.com/datasets/detect/#ultralytics-yolo-format ,  https://docs.ultralytics.com/modes/train/#idle-gpu-training
# https://docs.ultralytics.com/datasets/detect/construction-ppe/
#
# *   Albumentations docs (image augmentations)
# *   COCO ↔ YOLO conversion scripts (community repos)
# *   Papers for context: original YOLO, YOLOv3/v5/v8 family overviews
# *   data augmentation papers (Mosaic, MixUp, CutMix)

# %% [markdown]
# ### HW4.1. Dataset: Hard Hat Worker Safety (PPE detection)

# %% [markdown]
# Dataset:
# https://docs.ultralytics.com/datasets/detect/construction-ppe/
#
#
# *   What classes are present in the dataset, and how many classes are there in total?
# * How many images are included in the dataset?
# * What is the format of the ground-truth annotations as specified in data.yaml?

# %% [markdown]
# HW4.1 answers:

# %%
# Hello

# %% [markdown]
# ### HW4.2 Python Environment Setup
#
# Install libraries if needed:
#
#
# *   pip install ultralytics==8.* (or the latest available in your environment)
# *   Optional: pip install albumentations pycocotools opencv-python rich for augmentations/utilities

# %% [markdown]
# ### HW4.3 Dataset prep
# Download the dataset and convert the dataset into YOLO format if needed.
# Print out the number of instances per class for each dataset part (training, validation and test) and verify if the dataset is balanced.
# Augment dataset using albumentations library.

# %% [markdown]
# ###HW4.4 Baseline training
# Train a YOLO model (any of: yolov8n/s/m, or later equivalent) at imgsz=640 for 100 epochs or early stop.
# Save runs, config, logs, and best weights.

# %% [markdown]
# ###HW4.5 Ablation study
# Run one of:
# Input size: compare 640 vs 960 (or 512 vs 768 depending on GPU).
# Augmentations: turn on/off HSV, mosaic, mixup; or adjust degrees/translate/scale.
# LR schedule: cosine vs one-cycle; or different initial LR.
# Model scale: nano vs small (n vs s).

# %% [markdown]
# ###HW4.6 Evaluation & analysis
# Report: mAP@0.5 and mAP@[0.5:0.95], per-class AP, PR curves.
# Include qualitative results: correct detections, false positives, false negatives.
# Provide error taxonomy (occlusion, small objects, class confusion, clutter, domain shift).
